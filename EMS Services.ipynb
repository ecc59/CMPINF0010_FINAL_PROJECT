# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Import Panda

# %%
data = pd.read_csv("EMS.csv")
data.head(100)
# Out:
#     objectid          area      perimeter  rams  rams_id        acres  \
# 0          1  1.089535e+08   65491.364725    60      915  2501.229980
# 1          2  2.859605e+07   39150.158174    86      786   656.469971
# 2          3  1.006612e+08   76786.588197   103      762  2310.860107
# 3          4  7.606783e+07   44022.611587   105      836  1746.280029
# 4          5  1.501305e+08   71746.234269   160      818  3446.520020
# 5          6  2.760393e+08  140830.745425   168      976  6336.990234
# 6          7  6.954769e+07   51589.918404   205     1026  1596.599976
# 7          8  1.573417e+08   68299.331083   241      994  3612.070068
# 8          9  6.426495e+06   13292.970311     2     1046   147.529999
# 9         10  1.301189e+08   76119.105838     2     1046  2987.120117
# 10        11  7.156088e+06   14710.973511   206     1027   164.279999
# 11        12  9.837321e+07   87529.606123   206     1027  2258.340088
# 12        13  3.562026e+07   33928.642122   206     1027   817.729980
# 13        14  1.991990e+07   36762.702632   206     1027   457.299988
# 14        15  7.248282e+06   21424.146895   112      860   166.399994
# 15        16  3.389117e+07   35714.217862   112      860   778.030029
# 16        17  1.077439e+08   55963.706063     6      761  2473.459961
# 17        18  7.809345e+06   13583.073713     6      761   179.279999
# 18        19  2.127233e+06    9007.310451     9      798    48.830002
# 19        20  1.306248e+08   57392.206516     9      798  2998.729980
#
#     sqmiles  district    shape_area   shape_length
# 0      3.91         4  1.089535e+08   65491.366021
# 1      1.03         9  2.859605e+07   39150.158189
# 2      3.61        11  1.006612e+08   76786.588221
# 3      2.73         5  7.606784e+07   44022.612805
# 4      5.39         7  1.501305e+08   71746.234309
# 5      9.90         3  2.760393e+08  140830.746817
# 6      2.49         8  6.954769e+07   51589.918361
# 7      5.64         2  1.573417e+08   68299.331703
# 8      0.23        10  6.426495e+06   13292.970433
# 9      4.67        10  1.301189e+08   76119.105671
# 10     0.26        12  7.156089e+06   14710.973378
# 11     3.53        12  9.837321e+07   87529.607388
# 12     1.28        12  3.562026e+07   33928.642254
# 13     0.71        12  1.991990e+07   36762.702057
# 14     0.26        14  7.248282e+06   21424.146915
# 15     1.22        14  3.389117e+07   35714.217861
# 16     3.86         1  1.077439e+08   55963.706466
# 17     0.28         1  7.809344e+06   13583.073648
# 18     0.08         6  2.127233e+06    9007.309992
# 19     4.69         6  1.306248e+08   57392.206056

# %% [markdown]
# Import Data and Display the Table

# %%
data.plot()

# %% [markdown]
# Plot Initial Data

# %%
data = data.drop(columns = "area")
data = data.drop(columns = "perimeter")
data = data.drop(columns = "acres")
data = data.drop(columns = "rams")
data = data.drop(columns = "rams_id")
data = data.drop(columns = "sqmiles")
data = data.drop(columns = "shape_area")
data = data.drop(columns = "shape_length")
data.head(100)
# Out:
#     objectid  district
# 0          1         4
# 1          2         9
# 2          3        11
# 3          4         5
# 4          5         7
# 5          6         3
# 6          7         8
# 7          8         2
# 8          9        10
# 9         10        10
# 10        11        12
# 11        12        12
# 12        13        12
# 13        14        12
# 14        15        14
# 15        16        14
# 16        17         1
# 17        18         1
# 18        19         6
# 19        20         6

# %%
data["district"].value_counts().plot(kind='bar', rot=0)

# %% [markdown]
# Replot the Graph as a Bar Graph in Order to Easily Compare the amount of times the EMS Service came to help each Neighborhood

# %% [markdown]
# # Conclusion
#
# Based on this bar graph the best neighborhood would be a tie between 11, 9, 8, 7, 5, 4, 3, 2 because it had the least rescues, which means these districts would be safest due to the low service required.

# %% [markdown]
# These districts are a combination a multitude of neighborhoods, but there are overlaps with some of the other group members.
#
# These include Carrick, and Overbrook
